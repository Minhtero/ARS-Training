# %% [markdown]
# # 📘 Học OpenCV cơ bản (Tiếng Việt)
#
# Trong notebook này, chúng ta sẽ học **OpenCV** – thư viện xử lý ảnh rất quan trọng trong Computer Vision.
#
# Nội dung chính:
# 1. Đọc/ghi ảnh (`imread`, `imshow`, `imwrite`)
# 2. Resize ảnh
# 3. Chuyển màu Grayscale
# 4. Threshold nhị phân
# 5. Làm mờ Gaussian Blur
# 6. Bài tập nhỏ: xử lý ảnh PCB
#
# ---

# %% [markdown]
# ## 1. Cài đặt & Import thư viện

# %%
# Nếu chưa có thì cài đặt OpenCV (chỉ cần 1 lần)
# !pip install opencv-python matplotlib

import cv2
import matplotlib.pyplot as plt

print("OpenCV version:", cv2.__version__)
# Out:
# OpenCV version: 4.12.0

# %% [markdown]
# ## 2. Đọc/ghi ảnh

# %%
# Đọc ảnh (ví dụ: ảnh mặc định 'lena.png' hoặc ảnh bất kỳ em có)
# Ở đây thầy sẽ tạo 1 ảnh mẫu 128x128 để minh họa

import numpy as np

# Tạo ảnh RGB giả (màu ngẫu nhiên)
img = np.random.randint(0, 256, (128,128,3), dtype=np.uint8)

# Lưu ảnh
cv2.imwrite("sample.png", img)

# Đọc lại ảnh
img2 = cv2.imread("sample.png")

# Hiển thị ảnh với matplotlib (vì cv2.imshow không chạy được trên Colab)
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
plt.title("Ảnh gốc")
plt.axis("off")
plt.show()

# %% [markdown]
# ## 3. Resize ảnh

# %%
img_resized = cv2.resize(img2, (64,64))
plt.imshow(cv2.cvtColor(img_resized, cv2.COLOR_BGR2RGB))
plt.title("Ảnh resize 64x64")
plt.axis("off")
plt.show()

# %% [markdown]
# ## 4. Chuyển ảnh sang Grayscale

# %%
gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap="gray")
plt.title("Ảnh Grayscale")
plt.axis("off")
plt.show()

# %% [markdown]
# ## 5. Threshold nhị phân

# %%
# Threshold: giá trị > 127 = 255 (trắng), ngược lại = 0 (đen)
_, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
plt.imshow(binary, cmap="gray")
plt.title("Ảnh Threshold nhị phân")
plt.axis("off")
plt.show()

# %% [markdown]
# ## 6. Làm mờ Gaussian Blur

# %%
blur = cv2.GaussianBlur(gray, (5,5), 0)
plt.imshow(blur, cmap="gray")
plt.title("Ảnh làm mờ Gaussian Blur")
plt.axis("off")
plt.show()

# %% [markdown]
# ## 7. Bài tập nhỏ

# %% [markdown]
# 👉 Bài tập: Giả sử em có ảnh PCB (mạch in) 128×128.
# Hãy viết chương trình thực hiện các bước sau:
# 1. Đọc ảnh PCB (`pcb.png`).
# 2. Chuyển sang grayscale.
# 3. Resize về 128×128 (nếu chưa đúng).
# 4. Áp dụng threshold nhị phân.
# 5. Hiển thị kết quả cuối cùng.
#
# Gợi ý: thay `img2` bằng ảnh PCB thực tế của em.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img2 = np.random.randint(0, 256, (128,128,3), dtype=np.uint8)
img2 = cv2.imread("pcb.jpg")
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))

# %%
img_resized = cv2.resize(img2, (128,128))
plt.imshow(cv2.cvtColor(img_resized, cv2.COLOR_BGR2RGB))

# %%
gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap="gray")

# %%
img2 = np.random.randint(0, 256, (128,128,3), dtype=np.uint8)
img2 = cv2.imread("pcb.jpg")
img2 = cv2.resize(img2, (128,128))
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
_, img2 = cv2.threshold(img2, 127, 255, cv2.THRESH_BINARY)
plt.imshow(img2, cmap="gray")
